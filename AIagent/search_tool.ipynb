# %%
# libraries
from dotenv import load_dotenv
import os
from tavily import TavilyClient

# load environment variables from .env file
_ = load_dotenv()
# connect
client = TavilyClient(api_key=os.environ.get('TAVILY_API_KEY'))

# %%
# run search
result = client.search("What is in Nvidia's new Blackwell GPU?",
                       include_answer=True)
# print the answer
result["answer"]
# Out:
# 'The new Blackwell GPU from Nvidia features 24,064 CUDA cores, 96GB of GDDR7 memory, and a power consumption of 600W. It is designed for professional applications and includes advanced technologies such as the GB202-870 die with 192 SMs. The architecture is part of the broader Blackwell platform, which emphasizes generative AI and is supported by major tech companies.'

# %%
# choose location (try to change your own city!)

city = "shanghai"

query = f"""
What is the current weather in {city}?
Should I travel there today?
"""

# %% [markdown]
# 以下进行常规搜索

# %%
import requests
from bs4 import BeautifulSoup
from duckduckgo_search import DDGS
import re
ddg = DDGS()

def search (query, max_results=3):
    results = ddg.text(query, max_results=max_results)
    return [i["href"] for i in results]

for i in search(query):
    print(i)
# Out:
# https://www.accuweather.com/en/cn/shanghai/106577/weather-forecast/106577
# https://chinaweather.org/shanghai
# https://www.accuweather.com/en/cn/shanghai/106577/current-weather/106577

# %%
def scrape_weather_info(url):
    """Scrape content from URL"""
    if not url:
        return "Weather information not found"
    
    # fetch data
    headers = {'user-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return "Failed to retrieve the webpage."
    
    # parse result
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# use DuckDuckGo to find a websites and take the first result
url = search(query)[0]

# scrape first website
soup = scrape_weather_info(url)

print(f"Website: {url}\n\n")
print(soup)
# Out:
# Website: https://chinaweather.org/shanghai
#
#
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Shanghai Weather Forecast Today</title>
# <meta content="Stay updated on Shanghai's weather with real-time forecasts, temperature, humidity, and wind information." name="description"/>
# <link href="https://chinaweather.org/shanghai" rel="canonical"/>
# <link href="/static/CACHE/css/output.618b38ca6537.css" rel="stylesheet" type="text/css"/>
# <link href="https://chinaweather.org/shanghai" hreflang="en" rel="alternate" title="English" type="text/html"/>
# <link href="https://chinaweather.org/de/shanghai" hreflang="de" rel="alternate" title="Deutsch" type="text/html"/>
# <link href="https://chinaweather.org/nl/shanghai" hreflang="nl" rel="alternate" title="Nederlands" type="text/html"/>
# <link href="https://chinaweather.org/fr/shanghai" hreflang="fr" rel="alternate" title="Français" type="text/html"/>
# <link href="https://chinaweather.org/es/shanghai" hreflang="es" rel="alternate" title="Español" type="text/html"/>
# <link href="https://chinaweather.org/ca/shanghai" hreflang="ca" rel="alternate" title="Català" type="text/html"/>
# <link href="https://chinaweather.org/it/shanghai" hreflang="it" rel="alternate" title="Italiano" type="text/html"/>
# <link href="https://chinaweather.org/pt/shanghai" hreflang="pt" rel="alternate" title="Português (PT)" type="text/html"/>
# <link href="https://chinaweather.org/no/shanghai" hreflang="no" rel="alternate" title="Norsk" type="text/html"/>
# <link href="https://chinaweather.org/fi/shanghai" hreflang="fi" rel="alternate" title="Suomi" type="text/html"/>
# <link href="https://chinaweather.org/sv/shanghai" hreflang="sv" rel="alternate" title="Svenska" type="text/html"/>
# <link href="https://chinaweather.org/da/shanghai" hreflang="da" rel="alternate" title="Dansk" type="text/html"/>
# <link href="https://chinaweather.org/cs/shanghai" hreflang="cs" rel="alternate" title="Čeština" type="text/html"/>
# <link href="https://chinaweather.org/hu/shanghai" hreflang="hu" rel="alternate" title="Magyar" type="text/html"/>
# <link href="https://chinaweather.org/ro/shanghai" hreflang="ro" rel="alternate" title="Română" type="text/html"/>
# <link href="https://chinaweather.org/ja/shanghai" hreflang="ja" rel="alternate" title="日本語" type="text/html"/>
# <link href="https://chinaweather.org/zh-hans/shanghai" hreflang="zh-hans" rel="alternate" title="简体中文" type="text/html"/>
# <link href="https://chinaweather.org/zh-hant/shanghai" hreflang="zh-hant" rel="alternate" title="繁體中文" type="text/html"/>
# <link href="https://chinaweather.org/pl/shanghai" hreflang="pl" rel="alternate" title="Polski" type="text/html"/>
# <link href="https://chinaweather.org/el/shanghai" hreflang="el" rel="alternate" title="Ελληνικά" type="text/html"/>
# <link href="https://chinaweather.org/ru/shanghai" hreflang="ru" rel="alternate" title="Русский" type="text/html"/>
# <link href="https://chinaweather.org/tk/shanghai" hreflang="tk" rel="alternate" title="Türkçe" type="text/html"/>
# <link href="https://chinaweather.org/bg/shanghai" hreflang="bg" rel="alternate" title="Български" type="text/html"/>
# <link href="https://chinaweather.org/ar/shanghai" hreflang="ar" rel="alternate" title="العربية" type="text/html"/>
# <link href="https://chinaweather.org/ko/shanghai" hreflang="ko" rel="alternate" title="한국어" type="text/html"/>
# <link href="https://chinaweather.org/he/shanghai" hreflang="he" rel="alternate" title="עברית" type="text/html"/>
# <link href="https://chinaweather.org/lv/shanghai" hreflang="lv" rel="alternate" title="Latviski" type="text/html"/>
# <link href="https://chinaweather.org/uk/shanghai" hreflang="uk" rel="alternate" title="Українська" type="text/html"/>
# <link href="https://chinaweather.org/id/shanghai" hreflang="id" rel="alternate" title="Bahasa Indonesia" type="text/html"/>
# <link href="https://chinaweather.org/th/shanghai" hreflang="th" rel="alternate" title="ภาษาไทย" type="text/html"/>
# <link href="https://chinaweather.org/et/shanghai" hreflang="et" rel="alternate" title="Eesti" type="text/html"/>
# <link href="https://chinaweather.org/hr/shanghai" hreflang="hr" rel="alternate" title="Hrvatski" type="text/html"/>
# <link href="https://chinaweather.org/lt/shanghai" hreflang="lt" rel="alternate" title="Lietuvių" type="text/html"/>
# <link href="https://chinaweather.org/sk/shanghai" hreflang="sk" rel="alternate" title="Slovenčina" type="text/html"/>
# <link href="https://chinaweather.org/sr/shanghai" hreflang="sr" rel="alternate" title="Srpski" type="text/html"/>
# <link href="https://chinaweather.org/sl/shanghai" hreflang="sl" rel="alternate" title="Slovenščina" type="text/html"/>
# <link href="https://chinaweather.org/vi/shanghai" hreflang="vi" rel="alternate" title="Tiếng Việt" type="text/html"/>
# <link href="https://chinaweather.org/is/shanghai" hreflang="is" rel="alternate" title="Íslenska" type="text/html"/>
# <link href="https://chinaweather.org/favicon.svg" rel="icon" type="image/svg+xml"/>
# <link href="https://chinaweather.org/favicon192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://chinaweather.org/favicon.ico" rel="icon" sizes="32x32"/>
# <link href="https://chinaweather.org/favicon180x180.png" rel="apple-touch-icon">
# </link></head>
# <body>
# <header class="h">
# <div class="container-fluid">
# <div class="h_w">
# <div class="h_u">
# <a class="h_a" href="/"><i class="fflag fflag-CN"></i>China Weather</a>
# </div>
# <div class="h_bars hidden-lg hidden-md"><span></span></div>
# <div class="h_m">
# <div class="h_c hidden-sm hidden-xs">
# <span class="h_ct">Shanghai</span>
# <div class="h_cs">
# <ul>
# <li><a href="/guangdong">Guangdong</a></li>
# <li><a href="/sichuan">Sichuan</a></li>
# <li><a href="/beijing">Beijing</a></li>
# <li><a href="/tianjin">Tianjin</a></li>
# <li><a href="/liaoning">Liaoning</a></li>
# <li><a href="/anhui">Anhui</a></li>
# <li><a href="/tibet">Tibet</a></li>
# <li><a href="/guangxi">Guangxi</a></li>
# <li><a href="/zhejiang">Zhejiang</a></li>
# <li><a href="/shanxi">Shanxi</a></li>
# <li><a href="/chongqing">Chongqing</a></li>
# <li><a href="/gansu">Gansu</a></li>
# <li><a href="/hebei">Hebei</a></li>
# <li><a href="/jiangxi">Jiangxi</a></li>
# <li><a href="/shaanxi">Shaanxi</a></li>
# <li><a href="/xinjiang">Xinjiang</a></li>
# <li><a href="/hubei">Hubei</a></li>
# <li><a href="/fujian">Fujian</a></li>
# <li><a href="/jiangsu">Jiangsu</a></li>
# <li><a href="/jilin">Jilin</a></li>
# <li><a href="/hainan-china">Hainan</a></li>
# <li><a href="/heilongjiang">Heilongjiang</a></li>
# <li><a href="/yunnan">Yunnan</a></li>
# <li><a href="/guizhou">Guizhou</a></li>
# <li><a href="/inner-mongolia">Inner Mongolia</a></li>
# <li><a href="/qinghai">Qinghai</a></li>
# <li><a href="/hunan">Hunan</a></li>
# <li><a href="/ningxia">Ningxia</a></li>
# <li><a href="/shandong">Shandong</a></li>
# <li><a href="/henan">Henan</a></li>
# </ul>
# </div>
# </div>
# <form autocomplete="off" class="h_f" method="post"><input name="csrfmiddlewaretoken" type="hidden" value="ze7ChPaClyE2lA27WvG6t2lfMCdMnppJ3HF0DrMBEF6EvwVMOusu029qA4OzEY3p"/>
# <div class="h_fm autocomplete">
# <input class="form-control" id="search-home" placeholder="Search: City, Country, or Climate" required="required" type="text"/>
# </div>
# <button aria-label="Search" class="btn" type="button"><i class="fa fa-search"></i></button>
# <input id="lang_hidden" type="hidden" value="en"/>
# <input id="country_hidden" type="hidden" value="China"/>
# </form>
# </div>
# <ul class="h_n clear-fix">
# <li class="h_dl hidden-lg hidden-md">
# <a href="#">Shanghai <i class="fa fa-angle-down"></i></a>
# <ul class="h_s h_s4">
# <li><a href="/guangdong">Guangdong</a></li>
# <li><a href="/sichuan">Sichuan</a></li>
# <li><a href="/beijing">Beijing</a></li>
# <li><a href="/tianjin">Tianjin</a></li>
# <li><a href="/liaoning">Liaoning</a></li>
# <li><a href="/anhui">Anhui</a></li>
# <li><a href="/tibet">Tibet</a></li>
# <li><a href="/guangxi">Guangxi</a></li>
# <li><a href="/zhejiang">Zhejiang</a></li>
# <li><a href="/shanxi">Shanxi</a></li>
# <li><a href="/chongqing">Chongqing</a></li>
# <li><a href="/gansu">Gansu</a></li>
# <li><a href="/hebei">Hebei</a></li>
# <li><a href="/jiangxi">Jiangxi</a></li>
# <li><a href="/shaanxi">Shaanxi</a></li>
# <li><a href="/xinjiang">Xinjiang</a></li>
# <li><a href="/hubei">Hubei</a></li>
# <li><a href="/fujian">Fujian</a></li>
# <li><a href="/jiangsu">Jiangsu</a></li>
# <li><a href="/jilin">Jilin</a></li>
# <li><a href="/hainan-china">Hainan</a></li>
# <li><a href="/heilongjiang">Heilongjiang</a></li>
# <li><a href="/yunnan">Yunnan</a></li>
# <li><a href="/guizhou">Guizhou</a></li>
# <li><a href="/inner-mongolia">Inner Mongolia</a></li>
# <li><a href="/qinghai">Qinghai</a></li>
# <li><a href="/hunan">Hunan</a></li>
# <li><a href="/ningxia">Ningxia</a></li>
# <li><a href="/shandong">Shandong</a></li>
# <li><a href="/henan">Henan</a></li>
# </ul>
# </li>
# <li class="h_d h_dl">
# <a href="#" id="abc">Forecast <i class="fa fa-angle-down"></i></a>
# <ul class="h_s">
# <li><a href="/shanghai/hourly">Hourly Weather</a></li>
# <li><a href="/shanghai/3-day">3 Day Weather</a></li>
# <li><a href="/shanghai/7-day">7 Day Weather</a></li>
# <li><a href="/shanghai/10-day">10 Day Weather</a></li>
# <li><a href="/shanghai/14-day">14 Day Weather</a></li>
# <li><a href="/shanghai/30-day">30 Day Weather</a></li>
# </ul>
# </li>
# <li class="h_dl">
# <a href="#">Countries <i class="fa fa-angle-down"></i></a>
# <div class="h_s h_s3">
# <ul class="clear-fix">
# <li>
# <a href="https://albaniaweather.com" rel="nofollow">
# <i class="fflag fflag-AL" title="Albania"></i>
# <span>Albania</span>
# </a>
# </li>
# <li>
# <a href="https://algeriaweather.com" rel="nofollow">
# <i class="fflag fflag-DZ" title="Algeria"></i>
# <span>Algeria</span>
# </a>
# </li>
# <li>
# <a href="https://andorraweather.com" rel="nofollow">
# <i class="fflag fflag-AD" title="Andorra"></i>
# <span>Andorra</span>
# </a>
# </li>
# <li>
# <a href="https://argentinaweather.org" rel="nofollow">
# <i class="fflag fflag-AR" title="Argentina"></i>
# <span>Argentina</span>
# </a>
# </li>
# <li>
# <a href="https://australiaweather.org" rel="nofollow">
# <i class="fflag fflag-AU" title="Australia"></i>
# <span>Australia</span>
# </a>
# </li>
# <li>
# <a href="https://austriaweather.org" rel="nofollow">
# <i class="fflag fflag-AT" title="Austria"></i>
# <span>Austria</span>
# </a>
# </li>
# <li>
# <a href="https://azerbaijanweather.com" rel="nofollow">
# <i class="fflag fflag-AZ" title="Azerbaijan"></i>
# <span>Azerbaijan</span>
# </a>
# </li>
# <li>
# <a href="https://bahrain-weather.com" rel="nofollow">
# <i class="fflag fflag-BH" title="Bahrain"></i>
# <span>Bahrain</span>
# </a>
# </li>
# <li>
# <a href="https://belarusweather.org" rel="nofollow">
# <i class="fflag fflag-BY" title="Belarus"></i>
# <span>Belarus</span>
# </a>
# </li>
# <li>
# <a href="https://belgiumweather.org" rel="nofollow">
# <i class="fflag fflag-BE" title="Belgium"></i>
# <span>Belgium</span>
# </a>
# </li>
# <li>
# <a href="https://beninweather.com" rel="nofollow">
# <i class="fflag fflag-BJ" title="Benin"></i>
# <span>Benin</span>
# </a>
# </li>
# <li>
# <a href="https://bhutanweather.com" rel="nofollow">
# <i class="fflag fflag-BT" title="Bhutan"></i>
# <span>Bhutan</span>
# </a>
# </li>
# <li>
# <a href="https://bosniaweather.com" rel="nofollow">
# <i class="fflag fflag-BA" title="Bosnia and Herzegovina"></i>
# <span>Bosnia and Herzegovina</span>
# </a>
# </li>
# <li>
# <a href="https://botswanaweather.com" rel="nofollow">
# <i class="fflag fflag-BW" title="Botswana"></i>
# <span>Botswana</span>
# </a>
# </li>
# <li>
# <a href="https://brazilweather.org" rel="nofollow">
# <i class="fflag fflag-BR" title="Brazil"></i>
# <span>Brazil</span>
# </a>
# </li>
# <li>
# <a href="https://bulgariaweather.org" rel="nofollow">
# <i class="fflag fflag-BG" title="Bulgaria"></i>
# <span>Bulgaria</span>
# </a>
# </li>
# <li>
# <a href="https://burkinafasoweather.com" rel="nofollow">
# <i class="fflag fflag-BF" title="Burkina Faso"></i>
# <span>Burkina Faso</span>
# </a>
# </li>
# <li>
# <a href="https://burundiweather.com" rel="nofollow">
# <i class="fflag fflag-BI" title="Burundi"></i>
# <span>Burundi</span>
# </a>
# </li>
# <li>
# <a href="https://cambodiaweather.com" rel="nofollow">
# <i class="fflag fflag-KH" title="Cambodia"></i>
# <span>Cambodia</span>
# </a>
# </li>
# <li>
# <a href="https://cameroonweather.com" rel="nofollow">
# <i class="fflag fflag-CM" title="Cameroon"></i>
# <span>Cameroon</span>
# </a>
# </li>
# <li>
# <a href="https://canadaweather.org" rel="nofollow">
# <i class="fflag fflag-CA" title="Canada"></i>
# <span>Canada</span>
# </a>
# </li>
# <li>
# <a href="https://chileweather.org" rel="nofollow">
# <i class="fflag fflag-CL" title="Chile"></i>
# <span>Chile</span>
# </a>
# </li>
# <li>
# <a href="https://colombiaweather.org" rel="nofollow">
# <i class="fflag fflag-CO" title="Colombia"></i>
# <span>Colombia</span>
# </a>
# </li>
# <li>
# <a href="https://comorosweather.com" rel="nofollow">
# <i class="fflag fflag-KM" title="Comoros"></i>
# <span>Comoros</span>
# </a>
# </li>
# <li>
# <a href="https://croatiaweather.org" rel="nofollow">
# <i class="fflag fflag-HR" title="Croatia"></i>
# <span>Croatia</span>
# </a>
# </li>
# <li>
# <a href="https://cyprusweather.org" rel="nofollow">
# <i class="fflag fflag-CY" title="Cyprus"></i>
# <span>Cyprus</span>
# </a>
# </li>
# <li>
# <a href="https://czechiaweather.com" rel="nofollow">
# <i class="fflag fflag-CZ" title="Czechia"></i>
# <span>Czechia</span>
# </a>
# </li>
# <li>
# <a href="https://congoweather.com" rel="nofollow">
# <i class="fflag fflag-CD" title="Democratic Republic of the Congo"></i>
# <span>Democratic Republic of the Congo</span>
# </a>
# </li>
# <li>
# <a href="https://denmarkweather.org" rel="nofollow">
# <i class="fflag fflag-DK" title="Denmark"></i>
# <span>Denmark</span>
# </a>
# </li>
# <li>
# <a href="https://djiboutiweather.com" rel="nofollow">
# <i class="fflag fflag-DJ" title="Djibouti"></i>
# <span>Djibouti</span>
# </a>
# </li>
# <li>
# <a href="https://dominicaweather.org" rel="nofollow">
# <i class="fflag fflag-DM" title="Dominica"></i>
# <span>Dominica</span>
# </a>
# </li>
# <li>
# <a href="https://dominicanweather.org" rel="nofollow">
# <i class="fflag fflag-DO" title="Dominican Republic"></i>
# <span>Dominican Republic</span>
# </a>
# </li>
# <li>
# <a href="https://egyptweather.org" rel="nofollow">
# <i class="fflag fflag-EG" title="Egypt"></i>
# <span>Egypt</span>
# </a>
# </li>
# <li>
# <a href="https://eritreaweather.com" rel="nofollow">
# <i class="fflag fflag-ER" title="Eritrea"></i>
# <span>Eritrea</span>
# </a>
# </li>
# <li>
# <a href="https://estoniaweather.com" rel="nofollow">
# <i class="fflag fflag-EE" title="Estonia"></i>
# <span>Estonia</span>
# </a>
# </li>
# <li>
# <a href="https://eswatiniweather.com" rel="nofollow">
# <i class="fflag fflag-SZ" title="Eswatini"></i>
# <span>Eswatini</span>
# </a>
# </li>
# <li>
# <a href="https://micronesiaweather.com" rel="nofollow">
# <i class="fflag fflag-FM" title="Federated States of Micronesia"></i>
# <span>Federated States of Micronesia</span>
# </a>
# </li>
# <li>
# <a href="https://fijiweather.org" rel="nofollow">
# <i class="fflag fflag-FJ" title="Fiji"></i>
# <span>Fiji</span>
# </a>
# </li>
# <li>
# <a href="https://finlandweather.org" rel="nofollow">
# <i class="fflag fflag-FI" title="Finland"></i>
# <span>Finland</span>
# </a>
# </li>
# <li>
# <a href="https://franceweather.org" rel="nofollow">
# <i class="fflag fflag-FR" title="France"></i>
# <span>France</span>
# </a>
# </li>
# <li>
# <a href="https://gabonweather.com" rel="nofollow">
# <i class="fflag fflag-GA" title="Gabon"></i>
# <span>Gabon</span>
# </a>
# </li>
# <li>
# <a href="https://georgia-weather.com" rel="nofollow">
# <i class="fflag fflag-GE" title="Georgia"></i>
# <span>Georgia</span>
# </a>
# </li>
# <li>
# <a href="https://germanyweather.org" rel="nofollow">
# <i class="fflag fflag-DE" title="Germany"></i>
# <span>Germany</span>
# </a>
# </li>
# <li>
# <a href="https://ghanaweather.org" rel="nofollow">
# <i class="fflag fflag-GH" title="Ghana"></i>
# <span>Ghana</span>
# </a>
# </li>
# <li>
# <a href="https://greeceweather.org" rel="nofollow">
# <i class="fflag fflag-GR" title="Greece"></i>
# <span>Greece</span>
# </a>
# </li>
# <li>
# <a href="https://greenlandweather.com" rel="nofollow">
# <i class="fflag fflag-GL" title="Greenland"></i>
# <span>Greenland</span>
# </a>
# </li>
# <li>
# <a href="https://grenadaweather.com" rel="nofollow">
# <i class="fflag fflag-GD" title="Grenada"></i>
# <span>Grenada</span>
# </a>
# </li>
# <li>
# <a href="https://hongkongweather.org" rel="nofollow">
# <i class="fflag fflag-HK" title="Hong Kong"></i>
# <span>Hong Kong</span>
# </a>
# </li>
# <li>
# <a href="https://hungaryweather.org" rel="nofollow">
# <i class="fflag fflag-HU" title="Hungary"></i>
# <span>Hungary</span>
# </a>
# </li>
# <li>
# <a href="https://icelandweather.org" rel="nofollow">
# <i class="fflag fflag-IS" title="Iceland"></i>
# <span>Iceland</span>
# </a>
# </li>
# <li>
# <a href="https://weatherindia.org" rel="nofollow">
# <i class="fflag fflag-IN" title="India"></i>
# <span>India</span>
# </a>
# </li>
# <li>
# <a href="https://indonesiaweather.org" rel="nofollow">
# <i class="fflag fflag-ID" title="Indonesia"></i>
# <span>Indonesia</span>
# </a>
# </li>
# <li>
# <a href="https://irelandweather.org" rel="nofollow">
# <i class="fflag fflag-IE" title="Ireland"></i>
# <span>Ireland</span>
# </a>
# </li>
# <li>
# <a href="https://israelweather.org" rel="nofollow">
# <i class="fflag fflag-IL" title="Israel"></i>
# <span>Israel</span>
# </a>
# </li>
# <li>
# <a href="https://italyweather.org" rel="nofollow">
# <i class="fflag fflag-IT" title="Italy"></i>
# <span>Italy</span>
# </a>
# </li>
# <li>
# <a href="https://jamaicaweather.org" rel="nofollow">
# <i class="fflag fflag-JM" title="Jamaica"></i>
# <span>Jamaica</span>
# </a>
# </li>
# <li>
# <a href="https://japanweather.org" rel="nofollow">
# <i class="fflag fflag-JP" title="Japan"></i>
# <span>Japan</span>
# </a>
# </li>
# <li>
# <a href="https://kazakhstanweather.org" rel="nofollow">
# <i class="fflag fflag-KZ" title="Kazakhstan"></i>
# <span>Kazakhstan</span>
# </a>
# </li>
# <li>
# <a href="https://kiribatiweather.com" rel="nofollow">
# <i class="fflag fflag-KI" title="Kiribati"></i>
# <span>Kiribati</span>
# </a>
# </li>
# <li>
# <a href="https://laosweather.com" rel="nofollow">
# <i class="fflag fflag-LA" title="Laos"></i>
# <span>Laos</span>
# </a>
# </li>
# <li>
# <a href="https://latviaweather.org" rel="nofollow">
# <i class="fflag fflag-LV" title="Latvia"></i>
# <span>Latvia</span>
# </a>
# </li>
# <li>
# <a href="https://lesothoweather.com" rel="nofollow">
# <i class="fflag fflag-LS" title="Lesotho"></i>
# <span>Lesotho</span>
# </a>
# </li>
# <li>
# <a href="https://liberiaweather.com" rel="nofollow">
# <i class="fflag fflag-LR" title="Liberia"></i>
# <span>Liberia</span>
# </a>
# </li>
# <li>
# <a href="https://liechtensteinweather.com" rel="nofollow">
# <i class="fflag fflag-LI" title="Liechtenstein"></i>
# <span>Liechtenstein</span>
# </a>
# </li>
# <li>
# <a href="https://lithuaniaweather.com" rel="nofollow">
# <i class="fflag fflag-LT" title="Lithuania"></i>
# <span>Lithuania</span>
# </a>
# </li>
# <li>
# <a href="https://luxembourgweather.org" rel="nofollow">
# <i class="fflag fflag-LU" title="Luxembourg"></i>
# <span>Luxembourg</span>
# </a>
# </li>
# <li>
# <a href="https://madagascarweather.com" rel="nofollow">
# <i class="fflag fflag-MG" title="Madagascar"></i>
# <span>Madagascar</span>
# </a>
# </li>
# <li>
# <a href="https://malawiweather.com" rel="nofollow">
# <i class="fflag fflag-MW" title="Malawi"></i>
# <span>Malawi</span>
# </a>
# </li>
# <li>
# <a href="https://malaysiaweather.org" rel="nofollow">
# <i class="fflag fflag-MY" title="Malaysia"></i>
# <span>Malaysia</span>
# </a>
# </li>
# <li>
# <a href="https://mauritaniaweather.com" rel="nofollow">
# <i class="fflag fflag-MR" title="Mauritania"></i>
# <span>Mauritania</span>
# </a>
# </li>
# <li>
# <a href="https://mexicoweather.org" rel="nofollow">
# <i class="fflag fflag-MX" title="Mexico"></i>
# <span>Mexico</span>
# </a>
# </li>
# <li>
# <a href="https://moldovaweather.com" rel="nofollow">
# <i class="fflag fflag-MD" title="Moldova"></i>
# <span>Moldova</span>
# </a>
# </li>
# <li>
# <a href="https://mongolia-weather.com" rel="nofollow">
# <i class="fflag fflag-MN" title="Mongolia"></i>
# <span>Mongolia</span>
# </a>
# </li>
# <li>
# <a href="https://montenegroweather.com" rel="nofollow">
# <i class="fflag fflag-ME" title="Montenegro"></i>
# <span>Montenegro</span>
# </a>
# </li>
# <li>
# <a href="https://moroccoweather.org" rel="nofollow">
# <i class="fflag fflag-MA" title="Morocco"></i>
# <span>Morocco</span>
# </a>
# </li>
# <li>
# <a href="https://mozambiqueweather.com" rel="nofollow">
# <i class="fflag fflag-MZ" title="Mozambique"></i>
# <span>Mozambique</span>
# </a>
# </li>
# <li>
# <a href="https://myanmar-weather.com" rel="nofollow">
# <i class="fflag fflag-MM" title="Myanmar"></i>
# <span>Myanmar</span>
# </a>
# </li>
# <li>
# <a href="https://namibiaweather.com" rel="nofollow">
# <i class="fflag fflag-NA" title="Namibia"></i>
# <span>Namibia</span>
# </a>
# </li>
# <li>
# <a href="https://nauruweather.com" rel="nofollow">
# <i class="fflag fflag-NR" title="Nauru"></i>
# <span>Nauru</span>
# </a>
# </li>
# <li>
# <a href="https://netherlandsweather.org" rel="nofollow">
# <i class="fflag fflag-NL" title="Netherlands"></i>
# <span>Netherlands</span>
# </a>
# </li>
# <li>
# <a href="https://newcaledoniaweather.com" rel="nofollow">
# <i class="fflag fflag-NC" title="New Caledonia"></i>
# <span>New Caledonia</span>
# </a>
# </li>
# <li>
# <a href="https://newzealandweather.org" rel="nofollow">
# <i class="fflag fflag-NZ" title="New Zealand"></i>
# <span>New Zealand</span>
# </a>
# </li>
# <li>
# <a href="https://nicaraguaweather.com" rel="nofollow">
# <i class="fflag fflag-NI" title="Nicaragua"></i>
# <span>Nicaragua</span>
# </a>
# </li>
# <li>
# <a href="https://nigerweather.com" rel="nofollow">
# <i class="fflag fflag-NE" title="Niger"></i>
# <span>Niger</span>
# </a>
# </li>
# <li>
# <a href="https://nigeriaweather.org" rel="nofollow">
# <i class="fflag fflag-NG" title="Nigeria"></i>
# <span>Nigeria</span>
# </a>
# </li>
# <li>
# <a href="https://niueweather.com" rel="nofollow">
# <i class="fflag fflag-NU" title="Niue"></i>
# <span>Niue</span>
# </a>
# </li>
# <li>
# <a href="https://macedoniaweather.com" rel="nofollow">
# <i class="fflag fflag-MK" title="North Macedonia"></i>
# <span>North Macedonia</span>
# </a>
# </li>
# <li>
# <a href="https://norwayweather.org" rel="nofollow">
# <i class="fflag fflag-NO" title="Norway"></i>
# <span>Norway</span>
# </a>
# </li>
# <li>
# <a href="https://papuanewguineaweather.com" rel="nofollow">
# <i class="fflag fflag-PG" title="Papua New Guinea"></i>
# <span>Papua New Guinea</span>
# </a>
# </li>
# <li>
# <a href="https://paraguayweather.org" rel="nofollow">
# <i class="fflag fflag-PY" title="Paraguay"></i>
# <span>Paraguay</span>
# </a>
# </li>
# <li>
# <a href="https://peruweather.org" rel="nofollow">
# <i class="fflag fflag-PE" title="Peru"></i>
# <span>Peru</span>
# </a>
# </li>
# <li>
# <a href="https://philippinesweather.org" rel="nofollow">
# <i class="fflag fflag-PH" title="Philippines"></i>
# <span>Philippines</span>
# </a>
# </li>
# <li>
# <a href="https://polandweather.org" rel="nofollow">
# <i class="fflag fflag-PL" title="Poland"></i>
# <span>Poland</span>
# </a>
# </li>
# <li>
# <a href="https://portugalweather.org" rel="nofollow">
# <i class="fflag fflag-PT" title="Portugal"></i>
# <span>Portugal</span>
# </a>
# </li>
# <li>
# <a href="https://qatarweather.org" rel="nofollow">
# <i class="fflag fflag-QA" title="Qatar"></i>
# <span>Qatar</span>
# </a>
# </li>
# <li>
# <a href="https://romaniaweather.com" rel="nofollow">
# <i class="fflag fflag-RO" title="Romania"></i>
# <span>Romania</span>
# </a>
# </li>
# <li>
# <a href="https://russiaweather.org" rel="nofollow">
# <i class="fflag fflag-RU" title="Russia"></i>
# <span>Russia</span>
# </a>
# </li>
# <li>
# <a href="https://rwandaweather.com" rel="nofollow">
# <i class="fflag fflag-RW" title="Rwanda"></i>
# <span>Rwanda</span>
# </a>
# </li>
# <li>
# <a href="https://sanmarinoweather.com" rel="nofollow">
# <i class="fflag fflag-SM" title="San Marino"></i>
# <span>San Marino</span>
# </a>
# </li>
# <li>
# <a href="https://saudiarabiaweather.com" rel="nofollow">
# <i class="fflag fflag-SA" title="Saudi Arabia"></i>
# <span>Saudi Arabia</span>
# </a>
# </li>
# <li>
# <a href="https://serbiaweather.com" rel="nofollow">
# <i class="fflag fflag-RS" title="Serbia"></i>
# <span>Serbia</span>
# </a>
# </li>
# <li>
# <a href="https://seychellesweather.org" rel="nofollow">
# <i class="fflag fflag-SC" title="Seychelles"></i>
# <span>Seychelles</span>
# </a>
# </li>
# <li>
# <a href="https://sierraleoneweather.com" rel="nofollow">
# <i class="fflag fflag-SL" title="Sierra Leone"></i>
# <span>Sierra Leone</span>
# </a>
# </li>
# <li>
# <a href="https://weathersingapore.org" rel="nofollow">
# <i class="fflag fflag-SG" title="Singapore"></i>
# <span>Singapore</span>
# </a>
# </li>
# <li>
# <a href="https://slovakiaweather.com" rel="nofollow">
# <i class="fflag fflag-SK" title="Slovakia"></i>
# <span>Slovakia</span>
# </a>
# </li>
# <li>
# <a href="https://sloveniaweather.org" rel="nofollow">
# <i class="fflag fflag-SI" title="Slovenia"></i>
# <span>Slovenia</span>
# </a>
# </li>
# <li>
# <a href="https://southafricaweather.org" rel="nofollow">
# <i class="fflag fflag-ZA" title="South Africa"></i>
# <span>South Africa</span>
# </a>
# </li>
# <li>
# <a href="https://southkoreaweather.org" rel="nofollow">
# <i class="fflag fflag-KR" title="South Korea"></i>
# <span>South Korea</span>
# </a>
# </li>
# <li>
# <a href="https://spainweather.org" rel="nofollow">
# <i class="fflag fflag-ES" title="Spain"></i>
# <span>Spain</span>
# </a>
# </li>
# <li>
# <a href="https://srilankaweather.org" rel="nofollow">
# <i class="fflag fflag-LK" title="Sri Lanka"></i>
# <span>Sri Lanka</span>
# </a>
# </li>
# <li>
# <a href="https://surinameweather.com" rel="nofollow">
# <i class="fflag fflag-SR" title="Suriname"></i>
# <span>Suriname</span>
# </a>
# </li>
# <li>
# <a href="https://swedenweather.org" rel="nofollow">
# <i class="fflag fflag-SE" title="Sweden"></i>
# <span>Sweden</span>
# </a>
# </li>
# <li>
# <a href="https://switzerlandweather.org" rel="nofollow">
# <i class="fflag fflag-CH" title="Switzerland"></i>
# <span>Switzerland</span>
# </a>
# </li>
# <li>
# <a href="https://taiwanweather.org" rel="nofollow">
# <i class="fflag fflag-TW" title="Taiwan"></i>
# <span>Taiwan</span>
# </a>
# </li>
# <li>
# <a href="https://tajikistanweather.com" rel="nofollow">
# <i class="fflag fflag-TJ" title="Tajikistan"></i>
# <span>Tajikistan</span>
# </a>
# </li>
# <li>
# <a href="https://tanzaniaweather.com" rel="nofollow">
# <i class="fflag fflag-TZ" title="Tanzania"></i>
# <span>Tanzania</span>
# </a>
# </li>
# <li>
# <a href="https://thailandweather.org" rel="nofollow">
# <i class="fflag fflag-TH" title="Thailand"></i>
# <span>Thailand</span>
# </a>
# </li>
# <li>
# <a href="https://gambiaweather.com" rel="nofollow">
# <i class="fflag fflag-GM" title="The Gambia"></i>
# <span>The Gambia</span>
# </a>
# </li>
# <li>
# <a href="https://timorlesteweather.com" rel="nofollow">
# <i class="fflag fflag-TL" title="Timor-Leste"></i>
# <span>Timor-Leste</span>
# </a>
# </li>
# <li>
# <a href="https://tongaweather.com" rel="nofollow">
# <i class="fflag fflag-TO" title="Tonga"></i>
# <span>Tonga</span>
# </a>
# </li>
# <li>
# <a href="https://tunisiaweather.org" rel="nofollow">
# <i class="fflag fflag-TN" title="Tunisia"></i>
# <span>Tunisia</span>
# </a>
# </li>
# <li>
# <a href="https://turkeyweather.org" rel="nofollow">
# <i class="fflag fflag-TR" title="Turkey"></i>
# <span>Turkey</span>
# </a>
# </li>
# <li>
# <a href="https://turkmenistanweather.com" rel="nofollow">
# <i class="fflag fflag-TM" title="Turkmenistan"></i>
# <span>Turkmenistan</span>
# </a>
# </li>
# <li>
# <a href="https://ugandaweather.com" rel="nofollow">
# <i class="fflag fflag-UG" title="Uganda"></i>
# <span>Uganda</span>
# </a>
# </li>
# <li>
# <a href="https://ukraineweather.com" rel="nofollow">
# <i class="fflag fflag-UA" title="Ukraine"></i>
# <span>Ukraine</span>
# </a>
# </li>
# <li>
# <a href="https://uaeweather.org" rel="nofollow">
# <i class="fflag fflag-AE" title="United Arab Emirates"></i>
# <span>United Arab Emirates</span>
# </a>
# </li>
# <li>
# <a href="https://uk-weather.com" rel="nofollow">
# <i class="fflag fflag-GB" title="United Kingdom"></i>
# <span>United Kingdom</span>
# </a>
# </li>
# <li>
# <a href="https://uzbekistanweather.com" rel="nofollow">
# <i class="fflag fflag-UZ" title="Uzbekistan"></i>
# <span>Uzbekistan</span>
# </a>
# </li>
# <li>
# <a href="https://venezuelaweather.org" rel="nofollow">
# <i class="fflag fflag-VE" title="Venezuela"></i>
# <span>Venezuela</span>
# </a>
# </li>
# <li>
# <a href="https://vietnamweather.org" rel="nofollow">
# <i class="fflag fflag-VN" title="Vietnam"></i>
# <span>Vietnam</span>
# </a>
# </li>
# </ul>
# <div class="h_se"><a href="#">All countries</a></div>
# </div>
# </li>
# <li class="h_d h_dl">
# <a href="#">Metric (°C) <i class="fa fa-angle-down"></i></a>
# <ul class="h_s h_s2">
# <li><span>UNITS</span></li>
# <li><a href="#">Imperial (°F, mph, in)</a></li>
# <li><a href="#">Metric (°C, km/h, mm)</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </header>
# <main class="main-content">
# <div class="s5">
# <div class="container">
# <div class="s_h">
# <h1 class="s_t" id="weather">Shanghai, China Weather</h1>
# <p class="s_o">Current: 16.88°C/62.38°F, Wind SW at 17.89 km/h, 72% Humidity, 0% Chance of rain</p>
# </div>
# <div class="g2_d fos">
# <div class="g2_dt js-toc"></div>
# <ol class="g2_ds">
# <li class="active"><a href="#weather">Shanghai, China Weather</a></li>
# <li><a href="#current-conditions">Current conditions</a></li>
# <li><a href="#weather-forecast">Weather forecast</a></li>
# <li><a href="#averages-and-extremes">Averages and extremes</a></li>
# <li><a href="#yesterday-weather">Yesterday's Data</a></li>
# <li><a href="#temperature-in-next-12-hours">Temperature and possibility of rain in Shanghai over the next 12 hours</a></li>
# <li><a href="#temperature-next-7-days">Temperature and possibility of rain in Shanghai in the coming days</a></li>
# <li><a href="#rainfall-coming-days">Rainfall in Shanghai in the coming days</a></li>
# <li><a href="#weather-summary">Shanghai Weather Summary</a></li>
# <li><a href="#weather-by-month">Weather averages by month</a></li>
# <li><a href="#discticts">Shanghai's weather</a></li>
# <li><a href="#faqs">Frequently asked questions</a></li>
# <li><a href="#comments">Comments</a></li>
# </ol>
# </div>
# <div class="s5_g fl fls">
# <div class="s5_gc w1">
# <div class="s5_m">
# <figure class="s5_ma">
# <img alt="Shanghai,  Weather" class="lazy" data-original="https://images.unsplash.com/photo-1523281855495-b46cf55b1e7e?crop=entropy&amp;cs=srgb&amp;fm=jpg&amp;ixid=M3wyMzA4NjJ8MHwxfHNlYXJjaHwxfHxzaGFuZ2hhaS1jaGluYXxlbnwwfDB8fHwxNzEzNzkyOTY2fDA&amp;ixlib=rb-4.0.3&amp;q=85&amp;w=770&amp;h=400&amp;dpr=1"/>
# <figcaption class="s5_mn">(Photo by <a href="https://unsplash.com/@rleine?utm_source=tck&amp;utm_medium=referral" rel="nofollow" target="_blank">Ralf Leineweber</a> on <a href="https://unsplash.com/?utm_source=tck&amp;utm_medium=referral" rel="nofollow" target="_blank">Unsplash</a>)</figcaption>
# </figure>
# <div class="s5_mi">
# <div class="s5_mh grit">
# <h2 class="s5_mt" id="current-conditions">Current conditions</h2>
# <div class="s5_md">Updated: <span>16:43 PM Tuesday 11 March 2025</span></div>
# </div>
# <div class="s5_mb fos" id="sU">
# <div class="s5_a fl">
# <div class="s5_ah fl flc">
# <div class="s5_ak text-center">
# <div class="s5_au">
# <i class="iw iw-lg-04n"></i>
# <strong class="hidden-lg hidden-md hidden-sm"><strong>Overcast Clouds</strong></strong>
# </div>
# <div class="s5_as">
# <div class="temp s5_ao temp-c">13°C</div>
# <div class="temp s5_ao temp-f hide">55.4°F</div>
# <div class="s5_af">
# <span onclick="showTemp('temp-c')">°C</span>
# <span onclick="showTemp('temp-f')">°F</span>
# </div>
# </div>
# </div>
# </div>
# <div class="s5_ab">
# <div class="s5_ag fl">
# <div class="s5_ac">
# <p>Condition: <strong>Overcast Clouds</strong></p>
# <p>Pressure: <strong>1,017 hPa</strong></p>
# <p>Sea level: <strong>1,017 hPa</strong></p>
# <p>Temperature: <strong>12.61°C</strong></p>
# </div>
# <div class="s5_ac">
# <p>Cloud: <strong>99%</strong></p>
# <p>Humidity: <strong>89%</strong></p>
# <p>Wind: <strong>ESE 6.37 km/h</strong></p>
# <p>Visibility: <strong>10,000 m</strong></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="s5_mi">
# <div class="s5_mh grit">
# <h2 class="s5_mt" id="weather-forecast">Weather forecast</h2>
# <ul class="s5_ml fl">
# <li><a href="/shanghai/7-day">7 Days</a></li>
# <li><a href="/shanghai/10-day">10 Days</a></li>
# <li><a href="/shanghai/14-day">14 Days</a></li>
# <li><a href="/shanghai/30-day">30 Days</a></li>
# </ul>
# </div>
# <div class="s5_mb fos">
# <div class="s5_mz hidden-lg hidden-md hidden-sm"></div>
# <div class="s5_e fl">
# <div class="s5_ei">
# <div><strong>Tue</strong></div>
# <div>11 Mar</div>
# <div class="s5_ea"><i class="iw iw-lg-04d"></i></div>
# <div class="s5_en"><strong>19°C</strong></div>
# <div class="s5_ep"></div>
# <div>Broken Clouds</div>
# </div>
# <div class="s5_ei">
# <div><strong>Wed</strong></div>
# <div>12 Mar</div>
# <div class="s5_ea"><i class="iw iw-lg-10d"></i></div>
# <div class="s5_en"><strong>13°C</strong></div>
# <div class="s5_ep"></div>
# <div>Heavy Intensity Rain</div>
# </div>
# <div class="s5_ei">
# <div><strong>Thu</strong></div>
# <div>13 Mar</div>
# <div class="s5_ea"><i class="iw iw-lg-10d"></i></div>
# <div class="s5_en"><strong>10°C</strong></div>
# <div class="s5_ep"></div>
# <div>Light Rain</div>
# </div>
# <div class="s5_ei">
# <div><strong>Fri</strong></div>
# <div>14 Mar</div>
# <div class="s5_ea"><i class="iw iw-lg-10d"></i></div>
# <div class="s5_en"><strong>10°C</strong></div>
# <div class="s5_ep"></div>
# <div>Moderate Rain</div>
# </div>
# <div class="s5_ei">
# <div><strong>Sat</strong></div>
# <div>15 Mar</div>
# <div class="s5_ea"><i class="iw iw-lg-10d"></i></div>
# <div class="s5_en"><strong>9°C</strong></div>
# <div class="s5_ep"></div>
# <div>Light Rain</div>
# </div>
# </div>
# <div class="s5_k">
# <div class="s5_kh"><strong>Hourly forecast today:</strong></div>
# <div class="s5_km">
# <div class="s5_ki">
# <div class="s5_kd">23:00 PM</div>
# <div class="s5_ku">13° /  <strong>13°</strong></div>
# <div class="s5_ka"><i class="iw iw-lg-04n"></i></div>
# <div class="s5_kz">
# <div class="s5_kp">13° /  <strong>13°</strong></div>
# 	                                Overcast Clouds
# 	                            </div>
# <div class="s5_kf">
# <span><i class="iw iw-rain"></i>89%</span>
# <span><i class="iw iw-wind"></i>21.42 km/h</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="s5_mj fos hidden-lg hidden-md hidden-sm">
# <div class="s5_mg"></div>
# <ul class="s5_me">
# <li><strong>Normals:</strong> Max 20°C.  Min 10°C.</li>
# </ul>
# </div>
# <div class="s5_mi">
# <div class="s5_mh">
# <h2 class="s5_mt" id="averages-and-extremes">30 Day Averages and Extremes</h2>
# </div>
# <div class="s5_mb fos">
# <ul class="s5_l">
# <li>
# <span>Average high</span>
# <strong>15.74°C</strong>
# </li>
# <li>
# <span>Average low</span>
# <strong>10.15°C</strong>
# </li>
# <li>
# <span>Hottest day <span class="inline-block">(31 March 2025)</span></span>
# <strong>21.91°C</strong>
# </li>
# <li>
# <span>Coldest day <span class="inline-block">(17 March 2025)</span></span>
# <strong>4.54°C</strong>
# </li>
# <li>
# <span>Average humidity</span>
# <strong>69.63%</strong>
# </li>
# <li>
# <span>Days with precipitation</span>
# <strong>6 days</strong>
# </li>
# <li>
# <span>Highest precipitation</span>
# <strong>10.12 mm (14 March 2025)</strong>
# </li>
# </ul>
# </div>
# </div>
# <div class="s5_mi">
# <div class="s5_mh">
# <h2 class="s5_mt" id="yesterday-weather">Yesterday's Data</h2>
# </div>
# <div class="s5_mb fos">
# <ul class="s5_l">
# <li>
# <span>Max:</span>
# <strong>12°C</strong>
# </li>
# <li>
# <span>Min:</span>
# <strong>10°C</strong>
# </li>
# <li>
# <span>Total Precipitation:</span>
# <strong>0.84 mm</strong>
# </li>
# </ul>
# </div>
# </div>
# <div class="s5_mj">
# <h2 class="s5_mt" id="temperature-in-next-12-hours">Temperature and possibility of rain in Shanghai over the next 12 hours</h2>
# <div class="s5_mk fos">
# <canvas id="temperatureHour" style="display: block; box-sizing: border-box; height: 358.4px; width: 718.4px;">
# </canvas>
# </div>
# <input id="temper_hour" type="hidden" value='{"times": ["23:00"], "temp": [13], "rain": [0]}'/>
# </div>
# <div class="s5_mj">
# <h2 class="s5_mt" id="temperature-next-7-days">Temperature and possibility of rain in Shanghai in the coming days</h2>
# <div class="s5_mk fos">
# <canvas id="temperatureDay" style="display: block; box-sizing: border-box; height: 358.4px; width: 718.4px;">
# </canvas>
# </div>
# <input id="temper_day" type="hidden" value='{"times": ["Tue 11", "Wed 12", "Thu 13", "Fri 14", "Sat 15", "Sun 16", "Mon 17", "Tue 18", "Wed 19", "Thu 20", "Fri 21", "Sat 22"], "temp": [20, 15, 10, 10, 9, 12, 12, 13, 13, 15, 16, 20], "rain": [0, 100, 60, 100, 100, 100, 0, 0, 0, 0, 0, 0]}'/>
# </div>
# <div class="s5_mj">
# <h2 class="s5_mt" id="rainfall-coming-days">Rainfall in Shanghai in the coming days</h2>
# <div class="s5_mk fos">
# <canvas id="rainFalls" style="display: block; box-sizing: border-box; height: 358.4px; width: 718.4px;">
# </canvas>
# </div>
# <input id="rain_fall" type="hidden" value='{"times": ["Tue 11", "Wed 12", "Thu 13", "Fri 14", "Sat 15", "Sun 16", "Mon 17", "Tue 18", "Wed 19", "Thu 20", "Fri 21", "Sat 22"], "rain": [0, 7.3, 0.88, 10.12, 8.08, 0.39, 0, 0, 0, 0, 0, 0]}'/>
# </div>
# <div class="s5_mj">
# <h2 class="s5_mt" id="weather-summary">Shanghai Climate Summary</h2>
# <div class="s5_mc fos">
# <p>Shanghai features a Humid subtropical, no dry season (Köppen classification: Cfa), with an average annual temperature of 18.33ºC (64.99ºF), which is about 3.71% higher than the national average for China. Annually, the city experiences approximately 67.1 millimeters (2.64 inches) of rainfall, spread across 111.71 rainy days, accounting for 30.61% of the year.</p>
# <table class="tb1">
# <tr>
# <td>Longitude</td>
# <td>31.230416</td>
# </tr>
# <tr>
# <td>Latitude</td>
# <td>121.473701</td>
# </tr>
# <tr>
# <td>Yearly high temperature</td>
# <td>20.46ºC (68.83ºF)</td>
# </tr>
# <tr>
# <td>Yearly low temperature</td>
# <td>14.4ºC (57.92ºF)</td>
# </tr>
# <tr>
# <td>Hottest month</td>
# <td>June 27.13ºC (80.83ºF)</td>
# </tr>
# <tr>
# <td>Coldest month</td>
# <td>January 3.48ºC (38.26ºF)</td>
# </tr>
# <tr>
# <td>Yearly precip</td>
# <td>67.1mm (2.64in)</td>
# </tr>
# <tr>
# <td>Days with rainfall</td>
# <td>111.71 days (30.61%)</td>
# </tr>
# <tr>
# <td>Driest month</td>
# <td>November (68.14%)</td>
# </tr>
# <tr>
# <td>Wettest month</td>
# <td>June (79.74%)</td>
# </tr>
# </table>
# </div>
# </div>
# <div class="s5_mj">
# <h2 class="s5_mt" id="weather-by-month">Weather averages by month</h2>
# <div class="s5_mc fos">
# <table class="tb2">
# <tr>
# <th>Month</th>
# <th>High / Low (°C)</th>
# <th>Rain</th>
# </tr>
# <tr>
# <td>January</td>
# <td>8.45° / 3.48°</td>
# <td>7.36 days</td>
# </tr>
# <tr>
# <td>February</td>
# <td>9.86° / 4.07°</td>
# <td>8.18 days</td>
# </tr>
# <tr>
# <td>March</td>
# <td>14.17° / 6.97°</td>
# <td>9.64 days</td>
# </tr>
# <tr>
# <td>April</td>
# <td>19.63° / 11.52°</td>
# <td>6.36 days</td>
# </tr>
# <tr>
# <td>May</td>
# <td>24.73° / 17.41°</td>
# <td>9.09 days</td>
# </tr>
# <tr>
# <td>June</td>
# <td>27.13° / 21.26°</td>
# <td>13.55 days</td>
# </tr>
# <tr>
# <td>July</td>
# <td>31.29° / 25.23°</td>
# <td>15.27 days</td>
# </tr>
# <tr>
# <td>August</td>
# <td>31.84° / 25.96°</td>
# <td>13.18 days</td>
# </tr>
# <tr>
# <td>September</td>
# <td>27.38° / 21.82°</td>
# <td>10.09 days</td>
# </tr>
# <tr>
# <td>October</td>
# <td>22.63° / 16.97°</td>
# <td>5.45 days</td>
# </tr>
# <tr>
# <td>November</td>
# <td>17.6° / 12.41°</td>
# <td>7.09 days</td>
# </tr>
# <tr>
# <td>December</td>
# <td>10.78° / 5.74°</td>
# <td>6.45 days</td>
# </tr>
# </table>
# </div>
# </div>
# <div class="s5_mj">
# <h2 class="s5_mt" id="discticts">Shanghai's weather</h2>
# <div class="s5_mc fos">
# <ul class="s5_n fl showMoreCity">
# <li><a href="/shanghai/anting-town">Anting Town</a></li>
# <li><a href="/shanghai/baoshanlu-subdistrict">Baoshanlu Subdistrict</a></li>
# <li><a href="/shanghai/caohejing-subdistrict">Caohejing Subdistrict</a></li>
# <li><a href="/shanghai/changning-district">Changning District</a></li>
# <li><a href="/shanghai/chengqiao-town">Chengqiao Town</a></li>
# <li><a href="/shanghai/dachang-town">Dachang Town</a></li>
# <li><a href="/shanghai/dongminglu-subdistrict">Dongminglu Subdistrict</a></li>
# <li><a href="/shanghai/fengjing-town">Fengjing Town</a></li>
# <li><a href="/shanghai/ganquanlu-subdistrict">Ganquanlu Subdistrict</a></li>
# <li><a href="/shanghai/gaoxing-town">Gaoxing Town</a></li>
# <li><a href="/shanghai/gucun-town">Gucun Town</a></li>
# <li><a href="/shanghai/hongkou-district">Hongkou District</a></li>
# <li><a href="/shanghai/huangpu-district">Huangpu District</a></li>
# <li><a href="/shanghai/jiading-district">Jiading District</a></li>
# <li><a href="/shanghai/jiangninglu-subdistrict">Jiangninglu Subdistrict</a></li>
# <li><a href="/shanghai/jiangwanzhen-subdistrict">Jiangwanzhen Subdistrict</a></li>
# <li><a href="/shanghai/jinqiao-town">Jinqiao Town</a></li>
# <li><a href="/shanghai/jiuting-town">Jiuting Town</a></li>
# <li><a href="/shanghai/liangchengxincun-subdistrict">Liangchengxincun Subdistrict</a></li>
# <li><a href="/shanghai/lujiazui-subdistrict">Lujiazui Subdistrict</a></li>
# <li><a href="/shanghai/meilong-town">Meilong Town</a></li>
# <li><a href="/shanghai/nanqiao-town">Nanqiao Town</a></li>
# <li><a href="/shanghai/pinglianglu-subdistrict">Pinglianglu Subdistrict</a></li>
# <li><a href="/shanghai/putuo-district">Putuo District</a></li>
# <li><a href="/shanghai/qingpu-district">Qingpu District</a></li>
# <li><a href="/shanghai/shanggangxincun-subdistrict">Shanggangxincun Subdistrict</a></li>
# <li><a href="/shanghai/shihua-subdistrict">Shihua Subdistrict</a></li>
# <li><a href="/shanghai/xuhui-district">Xuhui District</a></li>
# <li><a href="/shanghai/baihe-town">Baihe Town</a></li>
# <li><a href="/shanghai/bansongyuanlu-subdistrict">Bansongyuanlu Subdistrict</a></li>
# <li><a href="/shanghai/baoshan-district">Baoshan District</a></li>
# <li><a href="/shanghai/beicai-town">Beicai Town</a></li>
# <li><a href="/shanghai/beizhan-subdistrict">Beizhan Subdistrict</a></li>
# <li><a href="/shanghai/caolu-town">Caolu Town</a></li>
# <li><a href="/shanghai/caoyangxincun-subdistrict">Caoyangxincun Subdistrict</a></li>
# <li><a href="/shanghai/changfengxincun-subdistrict">Changfengxincun Subdistrict</a></li>
# <li><a href="/shanghai/changqiao-subdistrict">Changqiao Subdistrict</a></li>
# <li><a href="/shanghai/changshoulu-subdistrict">Changshoulu Subdistrict</a></li>
# <li><a href="/shanghai/changxing-town">Changxing Town</a></li>
# <li><a href="/shanghai/changzheng-town">Changzheng Town</a></li>
# <li><a href="/shanghai/chedun-town">Chedun Town</a></li>
# <li><a href="/shanghai/chongming-district">Chongming District</a></li>
# <li><a href="/shanghai/chuansha-new-town">Chuansha New Town</a></li>
# <li><a href="/shanghai/daninglu-subdistrict">Daninglu Subdistrict</a></li>
# <li><a href="/shanghai/daqiao-subdistrict">Daqiao Subdistrict</a></li>
# <li><a href="/shanghai/dinghailu-subdistrict">Dinghailu Subdistrict</a></li>
# <li><a href="/shanghai/fangsong-subdistrict">Fangsong Subdistrict</a></li>
# <li><a href="/shanghai/fengcheng-town">Fengcheng Town</a></li>
# <li><a href="/shanghai/fenglinlu-subdistrict">Fenglinlu Subdistrict</a></li>
# <li><a href="/shanghai/fengxian-district">Fengxian District</a></li>
# <li><a href="/shanghai/gaodong-town">Gaodong Town</a></li>
# <li><a href="/shanghai/gaojing-town">Gaojing Town</a></li>
# <li><a href="/shanghai/gaoqiao-town">Gaoqiao Town</a></li>
# <li><a href="/shanghai/gonghexinlu-subdistrict">Gonghexinlu Subdistrict</a></li>
# <li><a href="/shanghai/guangzhonglu-subdistrict">Guangzhonglu Subdistrict</a></li>
# <li><a href="/shanghai/gumei-subdistrict">Gumei Subdistrict</a></li>
# <li><a href="/shanghai/hangtou-town">Hangtou Town</a></li>
# <li><a href="/shanghai/heqing-town">Heqing Town</a></li>
# <li><a href="/shanghai/hongqiao-town">Hongqiao Town</a></li>
# <li><a href="/shanghai/huacao-town">Huacao Town</a></li>
# <li><a href="/shanghai/huamu-subdistrict">Huamu Subdistrict</a></li>
# <li><a href="/shanghai/huaxin-town">Huaxin Town</a></li>
# <li><a href="/shanghai/hudongxincun-subdistrict">Hudongxincun Subdistrict</a></li>
# <li><a href="/shanghai/huinan-town">Huinan Town</a></li>
# <li><a href="/shanghai/jiadingzhen-subdistrict">Jiadingzhen Subdistrict</a></li>
# <li><a href="/shanghai/jiangchuanlu-subdistrict">Jiangchuanlu Subdistrict</a></li>
# <li><a href="/shanghai/jiangpulu-subdistrict">Jiangpulu Subdistrict</a></li>
# <li><a href="/shanghai/jiangqiao-town">Jiangqiao Town</a></li>
# <li><a href="/shanghai/jiaxinglu-subdistrict">Jiaxinglu Subdistrict</a></li>
# <li><a href="/shanghai/jing-an-district">Jing'an District</a></li>
# <li><a href="/shanghai/jinhui-town">Jinhui Town</a></li>
# <li><a href="/shanghai/jinshan-district">Jinshan District</a></li>
# <li><a href="/shanghai/jinyangxincun-subdistrict">Jinyangxincun Subdistrict</a></li>
# <li><a href="/shanghai/kangjianxincun-subdistrict">Kangjianxincun Subdistrict</a></li>
# <li><a href="/shanghai/kangqiao-town">Kangqiao Town</a></li>
# <li><a href="/shanghai/kongjianglu-subdistrict">Kongjianglu Subdistrict</a></li>
# <li><a href="/shanghai/linfenlu-subdistrict">Linfenlu Subdistrict</a></li>
# <li><a href="/shanghai/lingyunlu-subdistrict">Lingyunlu Subdistrict</a></li>
# <li><a href="/shanghai/longhua-subdistrict">Longhua Subdistrict</a></li>
# <li><a href="/shanghai/luodian-town">Luodian Town</a></li>
# <li><a href="/shanghai/malu-town">Malu Town</a></li>
# <li><a href="/shanghai/maqiao-town">Maqiao Town</a></li>
# <li><a href="/shanghai/minhang-district">Minhang District</a></li>
# <li><a href="/shanghai/nanmatoulu-subdistrict">Nanmatoulu Subdistrict</a></li>
# <li><a href="/shanghai/nanxiang-town">Nanxiang Town</a></li>
# <li><a href="/shanghai/pengpu-town">Pengpu Town</a></li>
# <li><a href="/shanghai/pengpuxincun-subdistrict">Pengpuxincun Subdistrict</a></li>
# <li><a href="/shanghai/pudong-new-district">Pudong New District</a></li>
# <li><a href="/shanghai/pujiang-town">Pujiang Town</a></li>
# <li><a href="/shanghai/puxinglu-subdistrict">Puxinglu Subdistrict</a></li>
# <li><a href="/shanghai/qibao-town">Qibao Town</a></li>
# <li><a href="/shanghai/qingcun-town">Qingcun Town</a></li>
# <li><a href="/shanghai/quyanglu-subdistrict">Quyanglu Subdistrict</a></li>
# <li><a href="/shanghai/sanlin-town">Sanlin Town</a></li>
# <li><a href="/shanghai/shanghai">Shanghai</a></li>
# <li><a href="/shanghai/shenzhuang-town">Shenzhuang Town</a></li>
# <li><a href="/shanghai/sheshan-town">Sheshan Town</a></li>
# <li><a href="/shanghai/shiquanlu-subdistrict">Shiquanlu Subdistrict</a></li>
# <li><a href="/shanghai/songjiang-district">Songjiang District</a></li>
# <li><a href="/shanghai/yangpu-district">Yangpu District</a></li>
# </ul>
# <a class="s5_v showMore" href="#">See more</a>
# </div>
# </div>
# <div class="s5_mj">
# <h2 class="s5_mt" id="faqs">Frequently asked questions</h2>
# <div class="s5_mc fos">
# <div class="s5_d">
# <div class="s5_di">
# <h3 class="s5_dt"><span>1.</span> What is the hottest month in Shanghai?</h3>
# <div class="s5_db">
# <p>June has the highest average monthly temperature (daily mean of 27.13ºC) and January are the coolest (daily mean of 3.48ºC).</p>
# </div>
# </div>
# <div class="s5_di">
# <h3 class="s5_dt"><span>2.</span> What should I wear in Shanghai today?</h3>
# <div class="s5_db">
# <p>For today's warm weather in Shanghai, with temperatures between 17ºC to 20ºC (62.6ºF to 68.0ºF), you might consider wearing:<br/> - Cotton or linen fabrics<br/> - Shorts or lightweight trousers<br/> - T-shirt or short-sleeve blouse<br/> - Sunglasses</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="s5_gc w2">
# <div class="wg fos">
# <div class="wg_i bg2">
# <h3 class="wg_h">Temperature</h3>
# <div class="wg_b">
# <div class="wg_a fl">
# <div class="wg_ai">
# <div><strong>Day</strong></div>
# <div class="wg_ao"><i class="iw iw-04d"></i></div>
# <div>19°C</div>
# </div>
# <div class="wg_ai">
# <div><strong>Night</strong></div>
# <div class="wg_ao"><i class="iw iw-04d"></i></div>
# <div>12°C</div>
# </div>
# <div class="wg_ai">
# <div><strong>Morning</strong></div>
# <div class="wg_ao"><i class="iw iw-04d"></i></div>
# <div>10°C</div>
# </div>
# <div class="wg_ai">
# <div><strong>Afternoon</strong></div>
# <div class="wg_ao"><i class="iw iw-04d"></i></div>
# <div>15°C</div>
# </div>
# </div>
# </div>
# </div>
# <div class="wg_i">
# <h3 class="wg_h">Air quality</h3>
# <div class="wg_b">
# <div class="wg_k">
# <strong class="wg_ka">Extreme</strong>
# <div class="wg_kc">
# <p>Hazardous air quality, serious health effects for everyone, strong precautions needed</p>
# </div>
# <ul class="wg_kl fl">
# <li>
# <strong>CO</strong>
# <span>2,777.1</span>
# </li>
# <li>
# <strong>NH<sub>3</sub></strong>
# <span>1.39</span>
# </li>
# <li>
# <strong>NO</strong>
# <span>110.87</span>
# </li>
# <li>
# <strong>NO<sub>2</sub></strong>
# <span>106.93</span>
# </li>
# <li>
# <strong>O<sub>3</sub></strong>
# <span>0</span>
# </li>
# <li>
# <strong>PM<sub>10</sub></strong>
# <span>183.3</span>
# </li>
# <li>
# <strong>PM<sub>25</sub></strong>
# <span>146.96</span>
# </li>
# <li>
# <strong>SO<sub>2</sub></strong>
# <span>162.13</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="wg_i bg2">
# <h3 class="wg_h">Sunrise / Sunset</h3>
# <div class="wg_b">
# <div class="wg_s fl">
# <div class="wg_si"><i class="iw iw-sunrise"></i>05:09 AM</div>
# <div class="wg_si"><i class="iw iw-sunset"></i> 16:59 PM</div>
# </div>
# </div>
# </div>
# <div class="wg_i wg_im">
# <h3 class="wg_h hidden-lg hidden-md">Shanghai Weather Map</h3>
# <div class="wg_b">
# <div class="wg_m">
# <div id="cityMap" style="width:100%;height:100%;object-fit:cover;object-position:center">
# <input id="city_map" type="hidden" value='{"point": [121.473701, 31.230416], "ename": "Shanghai"}'/>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <footer class="f">
# <div class="container">
# <div class="f_m">
# <div class="f_row clear-fix">
# <div class="f_col">
# <dl class="f_n">
# <dt>Popular locations:</dt>
# <dd><a href="/shanghai">Shanghai</a></dd>
# <dd><a href="/sichuan">Sichuan</a></dd>
# <dd><a href="/beijing">Beijing</a></dd>
# <dd><a href="/guangdong">Guangdong</a></dd>
# <dd><a href="/tianjin">Tianjin</a></dd>
# </dl>
# </div>
# <div class="f_col">
# <dl class="f_n">
# <dt>Site Information:</dt>
# <dd><a href="/widget">Weather Widget</a></dd>
# <dd><a href="/page/contact-us.html">Contact Us</a></dd>
# <dd><a href="/page/privacy-policy.html">Privacy Policy</a></dd>
# <dd><a href="/page/cookie-policy.html">Cookie Policy</a></dd>
# <dd><a href="/page/terms-conditions.html">Terms and Conditions</a></dd>
# </dl>
# </div>
# <div class="f_col">
# <div class="f_l">
# <div class="f_lt">English</div>
# <ul class="f_ls">
# <li><a href="/">English</a></li>
# <li><a href="/de">Deutsch</a></li>
# <li><a href="/nl">Nederlands</a></li>
# <li><a href="/fr">Français</a></li>
# <li><a href="/es">Español</a></li>
# <li><a href="/ca">Català</a></li>
# <li><a href="/it">Italiano</a></li>
# <li><a href="/pt">Português (PT)</a></li>
# <li><a href="/no">Norsk</a></li>
# <li><a href="/fi">Suomi</a></li>
# <li><a href="/sv">Svenska</a></li>
# <li><a href="/da">Dansk</a></li>
# <li><a href="/cs">Čeština</a></li>
# <li><a href="/hu">Magyar</a></li>
# <li><a href="/ro">Română</a></li>
# <li><a href="/ja">日本語</a></li>
# <li><a href="/zh-hans">简体中文</a></li>
# <li><a href="/zh-hant">繁體中文</a></li>
# <li><a href="/pl">Polski</a></li>
# <li><a href="/el">Ελληνικά</a></li>
# <li><a href="/ru">Русский</a></li>
# <li><a href="/tk">Türkçe</a></li>
# <li><a href="/bg">Български</a></li>
# <li><a href="/ar">العربية</a></li>
# <li><a href="/ko">한국어</a></li>
# <li><a href="/he">עברית</a></li>
# <li><a href="/lv">Latviski</a></li>
# <li><a href="/uk">Українська</a></li>
# <li><a href="/id">Bahasa Indonesia</a></li>
# <li><a href="/th">ภาษาไทย</a></li>
# <li><a href="/et">Eesti</a></li>
# <li><a href="/hr">Hrvatski</a></li>
# <li><a href="/lt">Lietuvių</a></li>
# <li><a href="/sk">Slovenčina</a></li>
# <li><a href="/sr">Srpski</a></li>
# <li><a href="/sl">Slovenščina</a></li>
# <li><a href="/vi">Tiếng Việt</a></li>
# <li><a href="/is">Íslenska</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="f_c">
# <p class="m0">Copyright © 2025 Chinaweather.Org - a Member of Weather and Climate Network</p>
# </div>
# </div>
# </footer>
# <div id="toTop">
# <span class="fa fa-arrow-up"></span>
# </div>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-3RJBXVM48L"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-3RJBXVM48L');
# </script>
# <script src="/static/CACHE/js/output.32ff03d2f804.js"></script>
# </body>
# </html>

# %%
# extract text
weather_data = []
for tag in soup.find_all(['h1', 'h2', 'h3', 'p']):
    text = tag.get_text(" ", strip=True)
    weather_data.append(text)

# combine all elements into a single string
weather_data = "\n".join(weather_data)

# remove all spaces from the combined text
weather_data = re.sub(r"\s+", " ", weather_data)

print (f"Website: {url}\n\n")
print (weather_data)
# Out:
# Website: https://chinaweather.org/shanghai
#
#
# Shanghai, China Weather Current: 16.88°C/62.38°F, Wind SW at 17.89 km/h, 72% Humidity, 0% Chance of rain Current conditions Condition: Overcast Clouds Pressure: 1,017 hPa Sea level: 1,017 hPa Temperature: 12.61°C Cloud: 99% Humidity: 89% Wind: ESE 6.37 km/h Visibility: 10,000 m Weather forecast 30 Day Averages and Extremes Yesterday's Data Temperature and possibility of rain in Shanghai over the next 12 hours Temperature and possibility of rain in Shanghai in the coming days Rainfall in Shanghai in the coming days Shanghai Climate Summary Shanghai features a Humid subtropical, no dry season (Köppen classification: Cfa), with an average annual temperature of 18.33ºC (64.99ºF), which is about 3.71% higher than the national average for China. Annually, the city experiences approximately 67.1 millimeters (2.64 inches) of rainfall, spread across 111.71 rainy days, accounting for 30.61% of the year. Weather averages by month Shanghai's weather Frequently asked questions 1. What is the hottest month in Shanghai? June has the highest average monthly temperature (daily mean of 27.13ºC) and January are the coolest (daily mean of 3.48ºC). 2. What should I wear in Shanghai today? For today's warm weather in Shanghai, with temperatures between 17ºC to 20ºC (62.6ºF to 68.0ºF), you might consider wearing: - Cotton or linen fabrics - Shorts or lightweight trousers - T-shirt or short-sleeve blouse - Sunglasses Temperature Air quality Hazardous air quality, serious health effects for everyone, strong precautions needed Sunrise / Sunset Shanghai Weather Map Copyright © 2025 Chinaweather.Org - a Member of Weather and Climate Network

# %%
# run search
result = client.search(query, max_results=1)

# print first result
data = result["results"][0]["content"]

print(data)
# Out:
# {'location': {'name': 'Shanghai', 'region': 'Shanghai', 'country': 'China', 'lat': 31.005, 'lon': 121.4086, 'tz_id': 'Asia/Shanghai', 'localtime_epoch': 1741710489, 'localtime': '2025-03-12 00:28'}, 'current': {'last_updated_epoch': 1741709700, 'last_updated': '2025-03-12 00:15', 'temp_c': 13.0, 'temp_f': 55.4, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 4.5, 'wind_kph': 7.2, 'wind_degree': 125, 'wind_dir': 'SE', 'pressure_mb': 1017.0, 'pressure_in': 30.03, 'precip_mm': 0.07, 'precip_in': 0.0, 'humidity': 94, 'cloud': 75, 'feelslike_c': 12.7, 'feelslike_f': 54.8, 'windchill_c': 11.8, 'windchill_f': 53.2, 'heatindex_c': 12.2, 'heatindex_f': 54.0, 'dewpoint_c': 11.3, 'dewpoint_f': 52.3, 'vis_km': 8.0, 'vis_miles': 4.0, 'uv': 0.0, 'gust_mph': 7.2, 'gust_kph': 11.6}}

# %%
import json
from pygments import highlight, lexers, formatters

# parse JSON
parsed_json = json.loads(data.replace("'", '"'))

# pretty print JSON with syntax highlighting
formatted_json = json.dumps(parsed_json, indent=4)
colorful_json = highlight(formatted_json, lexers.JsonLexer(), formatters.TerminalFormatter())
print(colorful_json)
# Out:
# {
#     "location": {
#         "name": "Shanghai",
#         "region": "Shanghai",
#         "country": "China",
#         "lat": 31.005,
#         "lon": 121.4086,
#         "tz_id": "Asia/Shanghai",
#         "localtime_epoch": 1741710489,
#         "localtime": "2025-03-12 00:28"
#     },
#     "current": {
#         "last_updated_epoch": 1741709700,
#         "last_updated": "2025-03-12 00:15",
#         "temp_c": 13.0,
#         "temp_f": 55.4,
#         "is_day": 0,
#         "condition": {
#             "text": "Partly cloudy",
#             "icon": "//cdn.weatherapi.com/weather/64x64/night/116.png",
#             "code": 1003
#         },
#         "wind_mph": 4.5,
#         "wind_kph": 7.2,
#         "wind_degree": 125,
#         "wind_dir": "SE",
#         "pressure_mb": 1017.0,
#         "pressure_in": 30.03,
#         "precip_mm": 0.07,
#         "precip_in": 0.0,
#         "humidity": 94,
#         "cloud": 75,
#         "feelslike_c": 12.7,
#         "feelslike_f": 54.8,
#         "windchill_c": 11.8,
#         "windchill_f": 53.2,
#         "heatindex_c": 12.2,
#         "heatindex_f": 54.0,
#         "dewpoint_c": 11.3,
#         "dewpoint_f": 52.3,
#         "vis_km": 8.0,
#         "vis_miles": 4.0,
#         "uv": 0.0,
#         "gust_mph": 7.2,
#         "gust_kph": 11.6
#     }
# }
